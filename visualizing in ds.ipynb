# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("Electric_Vehicle_Population_Data.csv")
# print(df.info())
sns.set_style("whitegrid")
plt.figure(figsize=(12,6))
#ev_population=df['Model Year'].value_counts().sort_index()
#print(ev_population)
sns.barplot(x=ev_population.index,y=ev_population.values)
plt.show()
