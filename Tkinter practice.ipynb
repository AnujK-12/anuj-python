# %%
import tkinter
from tkinter import *
def func():
    print("Anuj")
top=Tk()
top.configure(bg="black")
top.geometry("600x600")
l=Label(top,text="Hello World",fg="red",bg="pink")
l.pack()
l1=Label(top,text="Hello World 2")
l1.pack(side=BOTTOM)
l2=Button(top,text="Click here",command=func)
l2.pack(side=LEFT)
l3=Label(top,text="Keswani")
l3.place(x=365,y=369)
top.mainloop()

# %%
from tkinter import *
from country_list import b

def submit():
    g=gender.get()
    la1=cpp.get()
    la2=python.get()
    la3=java.get()
    print("Name: ",nameEntry.get())
    print("Email ID :",emailEntry.get())
    if g==1:
        print("Gender is Male")
    else:
        print("Gender is Female")
    if la1==1:
        print("C++")
    if la2==1:
        print("Python")
    if la3==1:
        print("java")
    print(l.get(l.curselection()))
    
    
top=Tk()
top.geometry("800x500")

# Creating Menu
menubar=Menu(top)
file=Menu(menubar,tearoff=0)
file.add_command(label="New File")
file.add_command(label="Save File")
file.add_command(label="Save As")
file.add_command(label="Open File")

menubar.add_cascade(label="Files",menu=file)
top.config(menu=menubar)
b1=Button(top,text="Exit",command=top.quit)
b1.grid(row=5,column=1)

nameLabel=Label(top,text="Enter your Name:")
nameEntry=Entry(top)
nameLabel.grid(row=0,column=0)
nameEntry.grid(row=0,column=1)

emailLabel=Label(top,text="Enter email ID:")
emailEntry=Entry(top)
emailLabel.grid(row=1,column=0)
emailEntry.grid(row=1,column=1)

gender=IntVar()
genderLabel=Label(top,text="Select your gender")
genderLabel.grid(row=2,column=0)
maleRadio=Radiobutton(top,text="Male",variable=gender,value=1)
femaleRadio=Radiobutton(top,text="Female",variable=gender,value=0)
maleRadio.grid(row=2,column=1)
femaleRadio.grid(row=2,column=2)

cpp=IntVar()
python=IntVar()
java=IntVar()
langLabel=Label(top,text="Select your languages")
l1=Checkbutton(top,text="C++",onvalue=1,offvalue=0,variable=cpp)
l2=Checkbutton(top,text="python",onvalue=1,offvalue=0,variable=python)
l3=Checkbutton(top,text="java",onvalue=1,offvalue=0,variable=java)
langLabel.grid(row=3,column=0)
l1.grid(row=3,column=1)
l2.grid(row=3,column=2)
l3.grid(row=3,column=3)

listlabel=Label(top,text="select your country")
l=Listbox(top)     #  list for few elements
# l.insert(0,"India")
# l.insert(1,"USA")
# l.insert(2,"Australia")
# l.insert(3,"UK")
print(b)
for i in b:
    l.insert(END,i)
    
listlabel.grid(row=4,column=0)
l.grid(row=4,column=1)



b=Button(top,text="Submit",command=submit)
b.grid(row=5,column=0)


top.mainloop()
# Out:
# ['India', 'USA', 'Russia', 'UK', 'Pakistan', 'Srilanka', 'Australia', 'Bangladesh', 'Singapor', 'Thailand', 'Dubai', 'Saudi Arabia', 'Poland']
# ['India', 'USA', 'Russia', 'UK', 'Pakistan', 'Srilanka', 'Australia', 'Bangladesh', 'Singapor', 'Thailand', 'Dubai', 'Saudi Arabia', 'Poland']
